# %% [markdown]
# ## Linear Regression with python
#
#                                     -Mridul mayank
#                                     Computer science business system
#                                     3rd year
#                                     RA1911042020026

# %% [markdown]
# ##  Implementation of Linear Regression on Heart Stroke prediction

# %% [markdown]
# ### Import the libraries

# %%
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ### Import Numpy and pandas libraries

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ### Import data visualization libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Import the dataset

# %%
df =pd.read_csv(r"C:\data sets\stroke.csv", encoding='ANSI')
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ### Handle the missing values

# %%
from sklearn.impute import SimpleImputer

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
df["bmi"]=df["bmi"].replace(np.NaN,df["bmi"].mean())
print(df["bmi"])
# Out:
# 0       36.600000
# 1       28.893237
# 2       32.500000
# 3       34.400000
# 4       24.000000
#           ...
# 5105    28.893237
# 5106    40.000000
# 5107    30.600000
# 5108    25.600000
# 5109    26.200000
# Name: bmi, Length: 5110, dtype: float64

# %% [markdown]
# ### Handling the categorical values

# %%
cat_cols =['gender','ever_married','work_type','Residence_type','smoking_status']
from sklearn.preprocessing import LabelEncoder
for each_col in cat_cols:
    Le=LabelEncoder()
    df[each_col]=Le.fit_transform (df[each_col])

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 0      9046       1  67.0             0              1             1
# 1     51676       0  61.0             0              0             1
# 2     31112       1  80.0             0              1             1
# 3     60182       0  49.0             0              0             1
# 4      1665       0  79.0             1              0             1
# ...     ...     ...   ...           ...            ...           ...
# 5105  18234       0  80.0             1              0             1
# 5106  44873       0  81.0             0              0             1
# 5107  19723       0  35.0             0              0             1
# 5108  37544       1  51.0             0              0             1
# 5109  44679       0  44.0             0              0             1
#
#       work_type  Residence_type  avg_glucose_level        bmi  smoking_status  \
# ...

# %% [markdown]
# ### Split the dataset into training and testing

# %%
x=df[['gender','age','hypertension','heart_disease','ever_married','work_type','Residence_type','avg_glucose_level','bmi',
      'smoking_status']].values
y=df[['stroke']].values
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size =0.8)

# %%
x_train.shape
# Out:
# (4088, 10)

# %%
x_test.shape
# Out:
# (1022, 10)

# %%
y_train.shape
# Out:
# (4088, 1)

# %%
y_test.shape
# Out:
# (1022, 1)

# %% [markdown]
# ### Import and perform linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr =LinearRegression()
lr.fit(x,y)
print("Our model has been Trained!!")
# Out:
# Our model has been Trained!!

# %% [markdown]
# ### Predict the values

# %%
y_pred =lr.predict(x_test)
y_pred.round(2)
# Out:
# array([[ 0.1 ],
#        [-0.  ],
#        [ 0.02],
#        ...,
#        [ 0.11],
#        [-0.02],
#        [ 0.12]])

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
check = pd.DataFrame(x_test,columns=['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
       'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
       'smoking_status'])

# %%
check["Stroke_actual"]=y_test

# %%
check['stroke_predicted']=y_pred.round(2)
check
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0        0.0  62.0           0.0            0.0           1.0        3.0
# 1        0.0  35.0           0.0            0.0           1.0        2.0
# 2        1.0  32.0           0.0            0.0           0.0        2.0
# 3        0.0  70.0           0.0            0.0           1.0        2.0
# 4        0.0  40.0           0.0            0.0           1.0        2.0
# ...      ...   ...           ...            ...           ...        ...
# 1017     1.0  60.0           0.0            0.0           1.0        2.0
# 1018     0.0  26.0           0.0            0.0           1.0        2.0
# 1019     0.0  65.0           0.0            0.0           0.0        3.0
# 1020     1.0  11.0           0.0            0.0           0.0        4.0
# 1021     0.0  78.0           0.0            0.0           1.0        2.0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  Stroke_actual  \
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mean_squared_error(y_test,y_pred)
# Out:
# 0.05033118442916943

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.1032169182662232
